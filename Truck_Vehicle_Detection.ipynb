# %% [markdown]
# <a href="https://colab.research.google.com/github/mfarizalarfn/Skripsi-ML-Classification-Truck-Vehicle/blob/main/Truck_Vehicle_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Machine Learning-Based Classification Of Truck Vehicles For A Comprehensive Algorithm Approach")
print("============================Mohamad Farizal Arifin============================================")
# Out:
# Machine Learning-Based Classification Of Truck Vehicles For A Comprehensive Algorithm Approach
# ============================Mohamad Farizal Arifin============================================

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install aspose-words

# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub
checks()  # checks
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.3/201.2 GB disk)

# %%
hub.login('ab153e527ca09db95cfcc5e7232fc34666c3bd0eb2')

model = YOLO('https://hub.ultralytics.com/models/4mzOb2Q90i8F7l2CdPtq')
results = model.train()
# Out:
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/4mzOb2Q90i8F7l2CdPtq 🚀
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 390MB/s]
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
r_evaluate = model.val()

print(r_evaluate)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /content/datasets/Cars Detection/labels/val.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|██████████| 112/112 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:03<00:00,  2.02it/s]
#                    all        112        295      0.863      0.703        0.8      0.575
#                    hat        112        214      0.851      0.799       0.85      0.627
#                 person        112         81      0.875      0.606      0.749      0.522
# ...

# %%
# Ambil metrik precission, recall, & mAP dari hasil evaluasi
precision = results.results_dict['metrics/precision(B)']
recall = results.results_dict['metrics/recall(B)']
mAP = results.results_dict['metrics/mAP50(B)']

# Hitung F1-Score
f1_score = 2 * (precision * recall) / (precision + recall)

print("Precision:", precision)
print("Recall:", recall)
print("mAP:", mAP)
print("F1-Score:", f1_score)
# Out:
# Precision: 0.8717301731049616
# Recall: 0.6996653974847121
# mAP: 0.797887428231626
# F1-Score: 0.7762774052316117

# %%
# Mendapatkan hasil evaluasi dari atribut results_dict
evaluation_results = r_evaluate.results_dict

# Menampilkan hasil evaluasi
print("Model Evaluation Results:")
for metric, value in evaluation_results.items():
  print(f"{metric}: {value}")
# Out:
# Model Evaluation Results:
# metrics/precision(B): 0.8628991550558498
# metrics/recall(B): 0.7025557728287197
# metrics/mAP50(B): 0.799761143191638
# metrics/mAP50-95(B): 0.5747804877186831
# fitness: 0.5972785532659787

# %%
# Load a model
model = YOLO('/content/yolov8m.pt') # load an official model
model = YOLO('/content/runs/detect/train/weights/best.pt') # load a custom model
# Validate the model
metrics = model.val() # no arguments needed, dataset and settings remembered
metrics.box.map       # map50-95
metrics.box.map50     # map50
metrics.box.map75     # map75
metrics.box.maps      # a list contains map50-95 of each category
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 365MB/s]
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /content/datasets/Cars Detection/labels/val.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|██████████| 112/112 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.66it/s]
#                    all        112        295      0.863      0.703        0.8      0.575
#                    hat        112        214      0.851      0.799       0.85      0.627
# ...

# %%
# Print model evaluation results
print("Model Evaluation Results:")
print( "Precision (P):", metrics.box.p)
print ("Recall (R):", metrics.box.r)
print ("mAP50:", metrics.box.map50)
print ("mAP50-95:", metrics.box.map)

# Precision dan recall dari hasil evaluasi
precision = metrics.box.p
recall = metrics.box.r

# Menghitung akurasi
accuracy = precision * recall
print ("Accuracy:", accuracy)
# Out:
# Model Evaluation Results:
# Precision (P): [     0.8506      0.8752]
# Recall (R): [    0.79907     0.60605]
# mAP50: 0.799761143191638
# mAP50-95: 0.5747804877186831
# Accuracy: [    0.67969     0.53041]

# %%
import matplotlib.pyplot as plt

# Replace '/actual/full/path/to/F1_curve.png' with the actual full path to your image file
img = plt.imread('/content/runs/detect/train/F1_curve.png')
plt.imshow(img)
plt.show()

# %%
img = plt.imread('/content/runs/detect/train/PR_curve.png')
plt.imshow(img)

# %%
img = plt.imread('/content/runs/detect/train/confusion_matrix.png')
plt.imshow(img)

# %%
img = plt.imread('/content/runs/detect/train/confusion_matrix_normalized.png')
plt.imshow(img)

# %%
img = plt.imread('/content/runs/detect/train/results.png')
plt.imshow(img)

# %%
img = plt.imread('/content/runs/detect/train/labels.jpg')
plt.imshow(img)

# %%
img = plt.imread('/content/runs/detect/train/val_batch0_pred.jpg')
plt.imshow(img)
